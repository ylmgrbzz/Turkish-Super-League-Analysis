# %% [markdown]
# <a href="https://colab.research.google.com/github/ylmgrbzz/Turkish-Super-League-Analysis/blob/main/Data%20Analysis%20of%20Turkish%20Super%20League%20with%20Python%20and%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
lig=pd.read_csv('tcl.csv', delimiter=";" )

# %%
lig
# Out:
#     year         team  played  won  drawn  lost  goals_for  goals_against  \
# 0   1959   Fenerbahce      16   13      2     1         33              8
# 1   1960     Besiktas      38   29      7     2         68             15
# 2   1961   Fenerbahce      38   26      9     3         81             29
# 3   1962  Galatasaray      38   23     11     4         52             18
# 4   1963  Galatasaray      22   14      7     1         54             14
# 5   1964   Fenerbahce      34   21     11     2         55             14
# 6   1965   Fenerbahce      30   18     11     1         52             13
# 7   1966     Besiktas      30   20      8     2         52             16
# 8   1967     Besiktas      32   16     13     3         44             15
# 9   1968   Fenerbahce      32   19     11     2         38             12
# 10  1969  Galatasaray      30   19      8     3         49             14
# 11  1970   Fenerbahce      30   17     10     3         31              6
# ...

# %%
lig.columns
# Out:
# Index(['year', 'team', 'played', 'won', 'drawn', 'lost', 'goals_for',
#        'goals_against', 'goal_difference', 'points'],
#       dtype='object')

# %%
lig.columns=["yil","takim","oyun","galibiyet","beraberlik",
             "maglubiyet","atilan_gol","yenilen_gol","averaj","puan"]

# %%
lig.head(3)
# Out:
#     yil       takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 0  1959  Fenerbahce    16         13           2           1          33
# 1  1960    Besiktas    38         29           7           2          68
# 2  1961  Fenerbahce    38         26           9           3          81
#
#    yenilen_gol  averaj  puan
# 0            8      25    28
# 1           15      53    65
# 2           29      52    61

# %%
lig.tail(3)
# Out:
#      yil        takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 57  2016     Besiktas    34         25           4           5          75
# 58  2017     Besiktas    34         23           8           3          73
# 59  2018  Galatasaray    34         24           3           7          75
#
#     yenilen_gol  averaj  puan
# 57           35      40    79
# 58           30      43    77
# 59           33      42    75

# %%
lig["puan_duzeltilmis"]=(lig["galibiyet"]*3)+lig["beraberlik"]*1

# %%
lig.head(10)
# Out:
#     yil        takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 0  1959   Fenerbahce    16         13           2           1          33
# 1  1960     Besiktas    38         29           7           2          68
# 2  1961   Fenerbahce    38         26           9           3          81
# 3  1962  Galatasaray    38         23          11           4          52
# 4  1963  Galatasaray    22         14           7           1          54
# 5  1964   Fenerbahce    34         21          11           2          55
# 6  1965   Fenerbahce    30         18          11           1          52
# 7  1966     Besiktas    30         20           8           2          52
# 8  1967     Besiktas    32         16          13           3          44
# 9  1968   Fenerbahce    32         19          11           2          38
#
#    yenilen_gol  averaj  puan  puan_duzeltilmis
# 0            8      25    28                41
# 1           15      53    65                94
# ...

# %%
[lig["puan"]==lig["puan_duzeltilmis"]]
# Out:
# [0     False
#  1     False
#  2     False
#  3     False
#  4     False
#  5     False
#  6     False
#  7     False
#  8     False
#  9     False
#  10    False
#  11    False
#  12    False
#  13    False
#  14    False
#  15    False
#  16    False
#  17    False
#  18    False
#  19    False
#  20    False
#  21    False
#  22    False
#  23    False
#  24    False
#  25    False
#  26    False
#  27    False
#  28    False
#  29     True
#  30     True
#  31     True
#  32     True
#  33     True
#  34     True
#  35     True
#  36     True
#  37     True
#  38     True
#  39     True
#  40     True
#  41     True
#  42     True
#  43     True
#  44     True
#  45     True
#  46     True
#  47     True
#  48     True
#  49     True
#  50     True
#  51     True
#  52     True
#  53     True
#  54     True
#  55     True
#  56     True
#  57     True
#  58     True
#  59     True
#  dtype: bool]

# %%
lig[lig["puan"]==lig["puan_duzeltilmis"]].iloc[[0]]
# Out:
#      yil        takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 29  1988  Galatasaray    38         27           9           2          86
#
#     yenilen_gol  averaj  puan  puan_duzeltilmis
# 29           35      51    90                90

# %%
lig.head(5)
# Out:
#     yil        takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 0  1959   Fenerbahce    16         13           2           1          33
# 1  1960     Besiktas    38         29           7           2          68
# 2  1961   Fenerbahce    38         26           9           3          81
# 3  1962  Galatasaray    38         23          11           4          52
# 4  1963  Galatasaray    22         14           7           1          54
#
#    yenilen_gol  averaj  puan  puan_duzeltilmis
# 0            8      25    28                41
# 1           15      53    65                94
# 2           29      52    61                87
# 3           18      34    57                80
# 4           14      40    35                49

# %%
lig["takim"]
# Out:
# 0      Fenerbahce
# 1        Besiktas
# 2      Fenerbahce
# 3     Galatasaray
# 4     Galatasaray
# 5      Fenerbahce
# 6      Fenerbahce
# 7        Besiktas
# 8        Besiktas
# 9      Fenerbahce
# 10    Galatasaray
# 11     Fenerbahce
# 12    Galatasaray
# 13    Galatasaray
# 14    Galatasaray
# 15     Fenerbahce
# 16     Fenerbahce
# 17    Trabzonspor
# 18    Trabzonspor
# 19     Fenerbahce
# 20    Trabzonspor
# 21    Trabzonspor
# 22    Trabzonspor
# 23       Besiktas
# 24     Fenerbahce
# 25    Trabzonspor
# 26     Fenerbahce
# 27       Besiktas
# 28    Galatasaray
# 29    Galatasaray
# 30     Fenerbahce
# 31       Besiktas
# 32       Besiktas
# 33       Besiktas
# 34    Galatasaray
# 35    Galatasaray
# 36       Besiktas
# 37     Fenerbahce
# 38    Galatasaray
# 39    Galatasaray
# 40    Galatasaray
# 41    Galatasaray
# 42     Fenerbahce
# 43    Galatasaray
# 44       Besiktas
# 45     Fenerbahce
# 46     Fenerbahce
# 47    Galatasaray
# 48     Fenerbahce
# 49    Galatasaray
# ...

# %%
lig["takim"].value_counts()
# Out:
# Galatasaray    21
# Fenerbahce     19
# Besiktas       13
# Trabzonspor     6
# Bursaspor       1
# Name: takim, dtype: int64

# %%
sampiyon=pd.DataFrame(lig["takim"].value_counts(dropna=False))

# %%
sampiyon
# Out:
#              takim
# Galatasaray     21
# Fenerbahce      19
# Besiktas        13
# Trabzonspor      6
# Bursaspor        1

# %%
sampiyon.to_excel("sampiyon.xlsx")

# %%
lig["takim"].unique()
# Out:
# array(['Fenerbahce', 'Besiktas', 'Galatasaray', 'Trabzonspor',
#        'Bursaspor'], dtype=object)

# %%
len(lig["takim"].unique())
# Out:
# 5

# %%
lig.head(3)
# Out:
#     yil       takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 0  1959  Fenerbahce    16         13           2           1          33
# 1  1960    Besiktas    38         29           7           2          68
# 2  1961  Fenerbahce    38         26           9           3          81
#
#    yenilen_gol  averaj  puan  puan_duzeltilmis
# 0            8      25    28                41
# 1           15      53    65                94
# 2           29      52    61                87

# %%
lig.groupby(by=["takim"])

# %%
lig.groupby(by=["takim"]).mean()
# Out:
#                      yil       oyun  galibiyet  beraberlik  maglubiyet  \
# takim
# Besiktas     1990.307692  33.230769  22.000000    8.615385    2.615385
# Bursaspor    2010.000000  34.000000  23.000000    6.000000    5.000000
# Fenerbahce   1984.684211  32.210526  20.736842    8.368421    3.105263
# Galatasaray  1992.380952  32.761905  22.000000    7.095238    3.666667
# Trabzonspor  1979.500000  30.666667  15.666667   11.333333    3.666667
#
#              atilan_gol  yenilen_gol     averaj       puan  puan_duzeltilmis
# takim
# Besiktas      62.769231    22.307692  40.461538  66.846154         74.615385
# Bursaspor     65.000000    26.000000  39.000000  75.000000         75.000000
# Fenerbahce    61.210526    22.736842  38.473684  60.210526         70.578947
# Galatasaray   66.571429    25.666667  40.904762  66.809524         73.095238
# Trabzonspor   36.666667    13.166667  23.500000  42.666667         58.333333

# %%
lig.groupby(by=["takim"]).count()
# Out:
#              yil  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# takim
# Besiktas      13    13         13          13          13          13
# Bursaspor      1     1          1           1           1           1
# Fenerbahce    19    19         19          19          19          19
# Galatasaray   21    21         21          21          21          21
# Trabzonspor    6     6          6           6           6           6
#
#              yenilen_gol  averaj  puan  puan_duzeltilmis
# takim
# Besiktas              13      13    13                13
# Bursaspor              1       1     1                 1
# Fenerbahce            19      19    19                19
# Galatasaray           21      21    21                21
# Trabzonspor            6       6     6                 6

# %%
lig.groupby(by=["takim","yil"]).count()
# Out:
#                   oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# takim       yil
# Besiktas    1960     1          1           1           1           1
#             1966     1          1           1           1           1
#             1967     1          1           1           1           1
#             1982     1          1           1           1           1
#             1986     1          1           1           1           1
#             1990     1          1           1           1           1
#             1991     1          1           1           1           1
#             1992     1          1           1           1           1
#             1995     1          1           1           1           1
#             2003     1          1           1           1           1
#             2009     1          1           1           1           1
#             2016     1          1           1           1           1
# ...

# %%
lig.groupby(by=["takim","yil"]).sum()
# Out:
#                   oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# takim       yil
# Besiktas    1960    38         29           7           2          68
#             1966    30         20           8           2          52
#             1967    32         16          13           3          44
#             1982    32         14          16           2          38
#             1986    36         22          12           2          65
#             1990    34         23           6           5          77
#             1991    30         20           9           1          63
#             1992    30         23           7           0          58
#             1995    34         24           7           3          80
#             2003    34         26           7           1          63
#             2009    34         21           8           5          60
#             2016    34         25           4           5          75
# ...

# %%
lig.head(3)
# Out:
#     yil       takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 0  1959  Fenerbahce    16         13           2           1          33
# 1  1960    Besiktas    38         29           7           2          68
# 2  1961  Fenerbahce    38         26           9           3          81
#
#    yenilen_gol  averaj  puan  puan_duzeltilmis
# 0            8      25    28                41
# 1           15      53    65                94
# 2           29      52    61                87

# %%
maxpuan=lig["puan_duzeltilmis"].max()
lig[lig["puan_duzeltilmis"]==maxpuan]
# Out:
#     yil     takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 1  1960  Besiktas    38         29           7           2          68
#
#    yenilen_gol  averaj  puan  puan_duzeltilmis
# 1           15      53    65                94

# %%
minpuan=lig["puan_duzeltilmis"].min()
lig[lig["puan_duzeltilmis"]==minpuan]
# Out:
#     yil       takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 0  1959  Fenerbahce    16         13           2           1          33
#
#    yenilen_gol  averaj  puan  puan_duzeltilmis
# 0            8      25    28                41

# %%
lig["ort_puan"]=lig["puan_duzeltilmis"]/lig["oyun"]

# %%
maxortpuan=lig["ort_puan"].max()
lig[lig["ort_puan"]==maxortpuan]
# Out:
#      yil       takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 30  1989  Fenerbahce    36         29           6           1         103
#
#     yenilen_gol  averaj  puan  puan_duzeltilmis  ort_puan
# 30           27      76    93                93  2.583333

# %%
minortpuan=lig["ort_puan"].min()
lig[lig["ort_puan"]==minortpuan]
# Out:
#      yil        takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 21  1980  Trabzonspor    30         12          15           3          25
#
#     yenilen_gol  averaj  puan  puan_duzeltilmis  ort_puan
# 21           11      14    39                51       1.7

# %%
lig["ort_gol"]=lig["atilan_gol"]/lig["oyun"]

# %%
maxortgol=lig["ort_gol"].max()
lig[lig["ort_gol"]==maxortgol]
# Out:
#      yil       takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 30  1989  Fenerbahce    36         29           6           1         103
#
#     yenilen_gol  averaj  puan  puan_duzeltilmis  ort_puan   ort_gol
# 30           27      76    93                93  2.583333  2.861111

# %%
maxortgol=lig["ort_gol"].min()
lig[lig["ort_gol"]==maxortgol]
# Out:
#      yil        takim  oyun  galibiyet  beraberlik  maglubiyet  atilan_gol  \
# 21  1980  Trabzonspor    30         12          15           3          25
#
#     yenilen_gol  averaj  puan  puan_duzeltilmis  ort_puan   ort_gol
# 21           11      14    39                51       1.7  0.833333

# %%
lig["ort_puan"].mean()
# Out:
# 2.187392790781916

# %%
lig["ort_gol"].mean()
# Out:
# 1.868372612867582
